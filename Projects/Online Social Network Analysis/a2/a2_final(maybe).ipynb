# %%
from collections import defaultdict
import copy
import facebook
import io
import matplotlib.pyplot as plt
import networkx as nx
import time
# %matplotlib inline

# %%
def read_graph():
    
    """f = open('edges.txt','r')
    for l in f.readlines():
      words = l.split("\t")
    f.close()"""

    
    return nx.read_edgelist("edges.txt", delimiter='\t')

graph = read_graph()
print('graph has %d nodes and %d edges' % 
      (graph.order(), graph.number_of_edges()))
# Out:
# graph has 5062 nodes and 6060 edges

# %%
# Nodes with highest degree.
sorted(graph.degree().items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [(u'ONE', 39),
#  (u'Bill & Melinda Gates Foundation', 39),
#  (u'NPR', 35),
#  (u'UN Women', 34),
#  (u'Women Deliver', 34),
#  (u'The New York Times', 34),
#  (u'I fucking love science', 33),
#  (u'Global Citizen', 33),
#  (u'Melinda Gates', 32),
#  (u'Show of Force: Social Good', 32)]

# %%
# I have provided this graph drawing method for you.
def draw_network(graph, draw_thresh=1, label_thresh=31,
                 min_node_sz=30, max_node_sz=200):
    """
    Draw a graph, filtering the nodes and labels based on degree.
    The size of nodes is proportional to degree.
    
    graph...........a networkx graph
    draw_thresh.....only draw nodes that have degree greater than this.
    label_thresh....only label nodes that have degree greater than this.
    min_node_size...smallest node size
    max_node_size...biggest node size
    """
    degrees = graph.degree()
    labels = {n: n for n, d in degrees.items() if d > label_thresh}
    plt.figure(figsize=(10,10))
    nodes_to_draw = [name for name, degree in degrees.items() if degree > draw_thresh]
    maxdegree = max(degrees.values())
    sz_range = max_node_sz - min_node_sz
    sizes = [min_node_sz + (1. * degrees[n] / maxdegree * sz_range)
             for n in nodes_to_draw]
    subgraph = graph.subgraph(nodes_to_draw)
    nx.draw_networkx(subgraph, alpha=.3, width=.3,
                     labels=labels, node_size=sizes)
    plt.axis("off")
    plt.show()
    
draw_network(graph)

# %%
def get_subgraph(graph, min_degree):
    """Return a subgraph containing nodes whose degree is
    greater than min_degree.
    Args:
      graph........a netwomrkx graph
      min_degree...degree threshold
    Returns:
      a networkx graph, filtered as defined above.
    """
    ###TODO
    ###
    x = [n for n in graph.nodes() if graph.degree(n) <= min_degree]
    graph.remove_nodes_from(x)
    return graph
    
subgraph = get_subgraph(graph, 1)
print('subgraph has %d nodes and %d edges' % 
      (subgraph.order(), subgraph.number_of_edges()))
# Out:
# subgraph has 712 nodes and 1710 edges

# %%
def girvan_newman(G, minsize=30, maxsize=100):
    """ Recursive implementation of the girvan_newman algorithm.
    This involves a couple modifications from our class code.
    
    - Rather than recompute betweenness after each edge is removed,
      only compute betweenness once per call to this method. That is,
      compute betweenness once, remove edges until multiple connected
      components are formed, then recurse.
      
    - Rather than return all communities, only return communities with
      size >= minsize and <= maxsize. To do this, halt recursion
      when this condition is met. E.g., if a split results in
      communities of size 50 and 200, the community of size 50
      will be added to the result set, while the community of size
      200 will be split again using a recursive call to this function.
      Similarly, if a split results in communities of size 50 and 1, 
      the size 50 community will be returned, while the size 1 community
      will not.
      
    **Note that the above procedure means that not all nodes will be
    assigned a community.
    
    Args:
    G.........a networkx graph
    minsize...the smallest acceptable size for a community
    maxsize...the largest acceptable size for a community

    Returns:
    A list of all discovered communities. This list is a list 
    of lists of strings. E.g., [['A', 'B'], ['C', 'D']] is a result
    containing two communities ((A,B) and (C,D)).
    """
    ###TODO
    ###
    
    if G.order() == 1:
        return [G.nodes()]
    
    
    def find_best_edge(G0):
        eb = nx.edge_betweenness_centrality(G0)
        # eb is dict of (edge, score) pairs, where higher is better
        # Return the edge with the highest score.
        return sorted(eb.items(), key=lambda x: x[1], reverse=True)

    edge_to_remove = find_best_edge(G)
#     print edge_to_remove[0][0]
    # Each component is a separate community. We cluster each of these.
    components = [c for c in nx.connected_component_subgraphs(G)]
#     indent = '   ' * depth  # for printing
#     while len(components) == 1:
#         print indent + 'removing', edge_to_remove
    for i in range(len(edge_to_remove)):
        G.remove_edge(*edge_to_remove[i][0])
        components = [c for c in nx.connected_component_subgraphs(G)]
        if len(components)!=1:
            break
    print "removed %d edges" % int(i+1)
    print "Component sizes = [%d, %d]" % (components[0].order(),components[1].order())
    
    result = []
#     print  indent + 'components=', result
    for c in components:
        if c.order() >= 30 and c.order() <=100:
            result.append(c.nodes())
            print "stopping at %d" % c.order()   
        if c.order() > 100:    
            result.extend(girvan_newman(c))
    
    return result
result = girvan_newman(subgraph.copy(), minsize=30, maxsize=100)
# Out:
# removed 87 edges
# Component sizes = [701, 11]
# removed 3 edges
# Component sizes = [695, 6]
# removed 6 edges
# Component sizes = [694, 1]
# removed 2 edges
# Component sizes = [693, 1]
# removed 3 edges
# Component sizes = [692, 1]
# removed 6 edges
# Component sizes = [691, 1]
# removed 2 edges
# Component sizes = [689, 2]
# removed 2 edges
# Component sizes = [688, 1]
# removed 1 edges
# Component sizes = [641, 47]
# removed 188 edges
# Component sizes = [634, 7]
# removed 4 edges
# Component sizes = [633, 1]
# removed 12 edges
# Component sizes = [632, 1]
# removed 8 edges
# Component sizes = [631, 1]
# removed 6 edges
# Component sizes = [630, 1]
# removed 2 edges
# Component sizes = [629, 1]
# removed 2 edges
# Component sizes = [628, 1]
# removed 1 edges
# Component sizes = [600, 28]
# removed 6 edges
# Component sizes = [599, 1]
# removed 6 edges
# Component sizes = [598, 1]
# removed 2 edges
# Component sizes = [597, 1]
# removed 1 edges
# Component sizes = [557, 40]
# removed 25 edges
# Component sizes = [554, 3]
# removed 13 edges
# Component sizes = [553, 1]
# removed 1 edges
# Component sizes = [546, 7]
# removed 2 edges
# Component sizes = [545, 1]
# removed 23 edges
# Component sizes = [544, 1]
# removed 5 edges
# Component sizes = [543, 1]
# removed 3 edges
# Component sizes = [542, 1]
# removed 4 edges
# Component sizes = [541, 1]
# removed 10 edges
# Component sizes = [540, 1]
# removed 4 edges
# Component sizes = [539, 1]
# removed 2 edges
# Component sizes = [538, 1]
# removed 9 edges
# Component sizes = [537, 1]
# removed 2 edges
# Component sizes = [536, 1]
# removed 3 edges
# Component sizes = [535, 1]
# removed 7 edges
# Component sizes = [534, 1]
# removed 3 edges
# Component sizes = [533, 1]
# removed 2 edges
# Component sizes = [532, 1]
# removed 2 edges
# Component sizes = [531, 1]
# removed 2 edges
# Component sizes = [530, 1]
# removed 2 edges
# Component sizes = [529, 1]
# removed 2 edges
# Component sizes = [528, 1]
# removed 2 edges
# Component sizes = [526, 2]
# removed 2 edges
# Component sizes = [525, 1]
# removed 3 edges
# Component sizes = [524, 1]
# removed 1 edges
# Component sizes = [139, 385]
# removed 10 edges
# Component sizes = [136, 3]
# removed 2 edges
# Component sizes = [135, 1]
# removed 2 edges
# Component sizes = [134, 1]
# removed 4 edges
# Component sizes = [133, 1]
# removed 1 edges
# Component sizes = [123, 10]
# removed 2 edges
# Component sizes = [115, 8]
# removed 4 edges
# Component sizes = [114, 1]
# removed 5 edges
# Component sizes = [113, 1]
# removed 3 edges
# Component sizes = [112, 1]
# removed 2 edges
# Component sizes = [111, 1]
# removed 1 edges
# Component sizes = [11, 100]
# stopping at 100
# removed 19 edges
# Component sizes = [384, 1]
# removed 4 edges
# Component sizes = [383, 1]
# removed 3 edges
# Component sizes = [382, 1]
# removed 1 edges
# Component sizes = [358, 24]
# removed 9 edges
# Component sizes = [357, 1]
# removed 4 edges
# Component sizes = [356, 1]
# removed 2 edges
# Component sizes = [355, 1]
# removed 6 edges
# Component sizes = [354, 1]
# removed 2 edges
# Component sizes = [338, 16]
# removed 2 edges
# Component sizes = [337, 1]
# removed 1 edges
# Component sizes = [323, 14]
# removed 6 edges
# Component sizes = [322, 1]
# removed 5 edges
# Component sizes = [321, 1]
# removed 2 edges
# Component sizes = [320, 1]
# removed 1 edges
# Component sizes = [306, 14]
# removed 27 edges
# Component sizes = [305, 1]
# removed 2 edges
# Component sizes = [304, 1]
# removed 8 edges
# Component sizes = [295, 9]
# removed 3 edges
# Component sizes = [294, 1]
# removed 2 edges
# Component sizes = [293, 1]
# removed 1 edges
# Component sizes = [283, 10]
# removed 3 edges
# Component sizes = [282, 1]
# removed 3 edges
# Component sizes = [281, 1]
# removed 2 edges
# Component sizes = [280, 1]
# removed 4 edges
# Component sizes = [257, 23]
# removed 34 edges
# Component sizes = [255, 2]
# removed 10 edges
# Component sizes = [254, 1]
# removed 3 edges
# Component sizes = [253, 1]
# removed 3 edges
# Component sizes = [252, 1]
# removed 3 edges
# Component sizes = [251, 1]
# removed 2 edges
# Component sizes = [250, 1]
# removed 3 edges
# Component sizes = [249, 1]
# removed 7 edges
# Component sizes = [248, 1]
# removed 3 edges
# Component sizes = [247, 1]
# removed 3 edges
# Component sizes = [246, 1]
# removed 1 edges
# Component sizes = [214, 32]
# removed 7 edges
# Component sizes = [213, 1]
# removed 3 edges
# Component sizes = [212, 1]
# removed 3 edges
# Component sizes = [211, 1]
# removed 1 edges
# Component sizes = [202, 9]
# removed 1 edges
# Component sizes = [195, 7]
# removed 3 edges
# Component sizes = [194, 1]
# removed 3 edges
# Component sizes = [193, 1]
# removed 5 edges
# Component sizes = [192, 1]
# removed 4 edges
# Component sizes = [191, 1]
# removed 2 edges
# Component sizes = [190, 1]
# removed 4 edges
# Component sizes = [189, 1]
# removed 3 edges
# Component sizes = [188, 1]
# removed 5 edges
# Component sizes = [187, 1]
# removed 6 edges
# Component sizes = [183, 4]
# removed 4 edges
# Component sizes = [182, 1]
# removed 2 edges
# Component sizes = [181, 1]
# removed 13 edges
# Component sizes = [180, 1]
# removed 2 edges
# Component sizes = [179, 1]
# removed 2 edges
# Component sizes = [178, 1]
# removed 2 edges
# Component sizes = [177, 1]
# removed 1 edges
# Component sizes = [68, 109]
# stopping at 68
# removed 2 edges
# Component sizes = [108, 1]
# removed 4 edges
# Component sizes = [107, 1]
# removed 2 edges
# Component sizes = [100, 7]
# stopping at 100
# stopping at 32
# stopping at 40
# stopping at 47

# %%
print('final cluster sizes:')
[len(x) for x in result]
# Out:
# final cluster sizes:
# [100, 68, 100, 32, 40, 47]

# %%
# Draw each cluster separately.
for cluster in result:
    draw_network(graph.subgraph(cluster), label_thresh=5, draw_thresh=0)

# %%
# Compute the normalized cut for each discovered cluster.
def volume(nodes, graph):
    """
    Compute the volume for a set of `nodes`, which
    is the number of edges in `graph` with at least one end in
    nodes.
    Args:
      nodes...a list of strings for the nodes to compute the volume of.
      graph...a networkx graph
    """ 
    ###TODO
    ###
    return len(graph.edges(nodes))

def cut(S, T, graph):
    """
    Compute the cut-set of the cut (S,T), which is
    the set of edges that have one endpoint in S and
    the other in T.
    Args:
      S.......set of nodes in first subset
      T.......set of nodes in second subset
      graph...networkx graph
    Returns:
      An int representing the cut-set.
    """
    ###TODO
    ###
    L = [(x,y) for x in S for y in T if graph.has_edge(x,y)]
    return len(L)

def norm_cut_v(S, T, graph):
    """
    The normalized cut value for the cut S/T. (See lec06.)
    Args:
      S.......set of nodes in first subset
      T.......set of nodes in second subset
      graph...networkx graph
    Returns:
      An float representing the normalized cut value
    """
    ###TODO
    ###
    cutx = cut(S,T,graph)
    vol1 = float(volume(S,graph))
    vol2 = float(volume(T,graph))
    norm_cut_val = (cutx/vol1)+(cutx/vol2)
    return norm_cut_val

def score_clusters(clusters, graph):
    """
    Compute the normalized cut value for each cluster returned 
    by the girvan newman algorithm above. To compute the value
    for one cluster, we consider the cut in which S is the
    proposed cluster, and T are all the other nodes in the graph.
    E.g., if the graph has nodes [A,B,C,D,E], and the proposed cluster
    is [A,B], then the cut value is computed on the cut
    S=[A,B], T=[C,D,E].
    
    Args:
      clusters....list of lists of strings representing the clusters
                  returned by the Girvan Newman algorithm.
      graph.......a networkx graph
    Returns:
      list of floats containing the normalized cut values for each cluster.
    """
    ###TODO
    ###
    norm_cut_val = []
    y = set(graph.nodes())
    for n in clusters:
        S = set(n)
        T = y - S
        norm_cut_val.append(norm_cut_v(S, T, graph))
    return norm_cut_val

score_clusters(result, subgraph)
# Out:
# [0.5394522186431889,
#  0.7112986541855564,
#  0.6125866583993509,
#  0.7394497863247863,
#  0.38487710745480397,
#  0.169372331833391]

# %%
result
# Out:
# [[u'TED-Ed',
#   u'The Atlantic',
#   u'Global Shapers - San Salvador Hub',
#   u'Generosity Day',
#   u'Longreads',
#   u'TED Books',
#   u'Co.Create',
#   u'Facebook Developers',
#   u'Entertainment Weekly',
#   u'Sue Desmond-Hellmann',
#   u'Today Show',
#   u'The Insatiable Traveler',
#   u'On Point Radio',
#   u'Global Shapers Community - Quito, Ecuador Hub',
#   u'TED Fellows',
#   u'ProPublica',
#   u'GE',
#   u'MediaStorm',
#   u'Human Rights Watch',
#   u'The Rachel Maddow Show',
#   u'The New Yorker',
#   u'International Center for Journalists',
#   u'UC San Francisco (UCSF)',
#   u'Global Shapers',
#   u'Mashable',
#   u'Do Something',
#   u'Co.Exist',
#   u'NPR',
#   u'Intrepid Sea, Air & Space Museum',
#   u'Radio Diaries',
#   u'Hubble Space Telescope',
#   u'NPR Politics',
#   u'Astronomy Picture of the Day (APOD)',
#   u'The New York Times Opinion Section',
#   u'Global Accelerator',
#   u'ClickHole',
#   u'Facebook',
#   u'SXSW',
#   u'Sports Illustrated',
#   u'George Takei',
#   u'PBS',
#   u'Fast Company',
#   u'Qualcomm',
#   u'Sylvia A. Earle',
#   u'The New York Times - The Learning Network',
#   u'WNYC Radio',
#   u'Ripple Effect Images',
#   u'Young Global Leaders',
#   u'Real Simple',
#   u'Napkin Labs',
#   u'TED Radio Hour',
#   u'WIRED',
#   u'TIME',
#   u'Nieman Journalism Lab',
#   u'Ezra Klein',
#   u'Harvard Business Review',
#   u'This American Life',
#   u'UNFCCC',
#   u'Bill Nye The Science Guy',
#   u'TED',
#   u'TEDx',
#   u'Mother Jones',
#   u'TechCrunch',
#   u'Science',
#   u'TEDActive',
#   u'Fareed Zakaria',
#   u'The Onion',
#   u'FOX Sports',
#   u'Stanford Graduate School of Business',
#   u'Vox',
#   u'Radiolab',
#   u"NPR's Weekend Edition",
#   u'Global Shapers Monterrey Hub',
#   u'NPR Morning Edition',
#   u'NPR Extra',
#   u'International Space Station',
#   u'MSN',
#   u'Washington Post',
#   u'The Economist',
#   u'Snap Judgment',
#   u'I fucking love science',
#   u'AJ+',
#   u'Global Shapers - Santo Domingo Hub',
#   u'The Square',
#   u'indieWIRE',
#   u'Foro Econ\xf3mico Mundial',
#   u'GOOD',
#   u'Pandora',
#   u'CNN',
#   u'National Geographic',
#   u'MythBusters',
#   u'TED Live',
#   u'Nicholas Kristof',
#   u'The New York Times',
#   u'TIME Photo',
#   u'Kickstarter',
#   u'Slate.com',
#   u'TED.com',
#   u'Magnum Photos',
#   u'Pulitzer Center on Crisis Reporting'],
#  [u'Peace Corps',
#   u"International Women's Day",
#   u'Jeffrey Sachs',
#   u'The Ella Rose Collection',
#   u'SportsUnited - U.S. Department of State',
#   u"Department of State -- Office of Global Women's Issues",
#   u'Global Fund Advocates Network',
#   u'Save the Children',
#   u'MTV Issues',
#   u'Lalela Project',
#   u'Bread for the World',
#   u'loveLife',
#   u'Doctors Without Borders/ M\xe9decins Sans Fronti\xe8res (MSF)',
#   u'Al Jazeera Channel - \u0642\u0646\u0627\u0629 \u0627\u0644\u062c\u0632\u064a\u0631\u0629 \u0627\u0644\u0641\u0636\u0627\u0626\u064a\u0629',
#   u'KA Lite',
#   u'Global Entrepreneurship Week',
#   u'EFA Report UNESCO',
#   u'United Against Malaria',
#   u'Results for Development Institute',
#   u'We Are Africa United',
#   u'Population Services International',
#   u'Martha MacCallum',
#   u'Partners In Health',
#   u'Malaria No More UK',
#   u'Nonprofit Organizations',
#   u'OWN: Oprah Winfrey Network',
#   u'The Brookings Institution',
#   u'Africa Inside Out',
#   u'U.S. Global Leadership Coalition (USGLC)',
#   u'Grassroot Soccer',
#   u'streetfootballworld',
#   u'Stomp Out Malaria',
#   u'Global Education & Skills Forum',
#   u'Senator Patrick Leahy',
#   u'Sasha Alexander',
#   u'United Nations Mission in South Sudan (UNMISS)',
#   u'North American Power',
#   u'Roll Back Malaria',
#   u'Shot@Life',
#   u'United Nations Foundation',
#   u'U.S. Department of State: Engaging the Community on Foreign Affairs',
#   u'Donate My Card',
#   u'MDG Health Envoy',
#   u'Malaria No More',
#   u'CARE',
#   u'State Department- Bureau of International Security and Nonproliferation',
#   u'Women in Public Service',
#   u'U.S. Department of State: Bureau of African Affairs',
#   u'U.S. Department of State:  Bureau of Population, Refugees, and Migration',
#   u'UNICEF Africa',
#   u'U.S. Department of State',
#   u"Samuel Eto'o",
#   u'Swiss Malaria Foundation',
#   u'Stop TB Partnership',
#   u'Qatar Foundation',
#   u'Save the Children UK',
#   u'Jack Wills',
#   u'Unicef Liberia',
#   u'Speak Up Africa',
#   u'Global Health and Diplomacy',
#   u'UNITAID',
#   u"General Federation of Women's Clubs",
#   u'Infosys',
#   u'Zinduka! Malaria Haikubaliki',
#   u"The U.S. President's Emergency Plan for AIDS Relief (PEPFAR)",
#   u'The Malaria Policy Center',
#   u'Global Good Challenge',
#   u'Yvonne Chaka Chaka'],
#  [u'Washington Global Health Alliance',
#   u'UN-Water World Water Day',
#   u'SOIL (Sustainable Organic Integrated Livelihoods)',
#   u'Evidence Action',
#   u'World Federation of United Nations Associations',
#   u'Overseas Private Investment Corporation',
#   u'Nothing But Nets',
#   u'Operation ASHA',
#   u'United Nations Millennium Campaign Africa',
#   u'Devex',
#   u'The White House',
#   u'allAfrica.com',
#   u'UNIDO - United Nations Industrial Development Organization',
#   u'UNFPA',
#   u'World YWCA',
#   u'myweku.com',
#   u'Sandra Rotman Centre',
#   u'The Better World Campaign',
#   u'Instagram',
#   u'UNICEF',
#   u'Grameen Foundation',
#   u"Office of the UN Secretary-General's Envoy on Youth",
#   u'ICDDR,B',
#   u'Global Goals for Sustainable Development',
#   u'United Nations Development Programme - UNDP',
#   u'Global Communities',
#   u'Grand Challenges Canada',
#   u'Rio+20 UN Conference on Sustainable Development',
#   u'UN Sustainable Development Knowledge Platform',
#   u'International Fund for Agricultural Development (IFAD)',
#   u'Children and Youth International',
#   u'United Nations Regional Information Centre- UNRIC',
#   u'Global Alliance for Clean Cookstoves',
#   u'UN-HABITAT',
#   u'The Lancet',
#   u'Abdul Latif Jameel Poverty Action Lab (J-PAL)',
#   u'CGAP - Consultative Group to Assist the Poor',
#   u'International Committee of the Red Cross',
#   u'The Commonwealth',
#   u'The Global Fund for Women',
#   u'UNAIDS',
#   u'Oxfam Ireland',
#   u'UNODC - United Nations Office on Drugs and Crime',
#   u'Cordaid',
#   u'UNDP in the Pacific and PNG',
#   u'International Atomic Energy Agency (IAEA)',
#   u'International Labour Organization (ILO)',
#   u'Gavi, the Vaccine Alliance',
#   u'Rio+20',
#   u'United Nations Human Rights',
#   u'INSEAD Knowledge',
#   u'African Green Revolution Forum',
#   u'UN Women',
#   u'World Health Organization (WHO)',
#   u'VillageReach',
#   u'United Nations in Thailand',
#   u'United Nations Association of New Zealand - UNANZ',
#   u'PATH Drug Development',
#   u'UNMEER',
#   u'United Nations Assistance Mission for Iraq (UNAMI)',
#   u"Women's Major Group",
#   u'United Nations Commission on the Status of Women (CSW)',
#   u'Power the World',
#   u'Desmond Tutu HIV Foundation',
#   u'Governor-General of New Zealand',
#   u'Sustainable Energy for All',
#   u"The United Nations Girls' Education Initiative -(UNGEI)",
#   u'United Nations in Belarus',
#   u'UN Geneva',
#   u'United Nations Photo',
#   u'World Bank',
#   u'UNDP Albania',
#   u'Helen Clark',
#   u'Schwab Foundation for Social Entrepreneurship',
#   u'UN Web TV',
#   u'United Nations Assistance Mission in Somalia - UNSOM',
#   u'Rio+Social',
#   u'UN Women Pacific',
#   u'WHO Regional Office for Europe',
#   u'UNESCO',
#   u'United Nations',
#   u'United Nations Visitors Centre',
#   u'United Nations News Centre',
#   u'One Day On Earth',
#   u'IRIN',
#   u'United Nations Millennium Campaign',
#   u'World Food Programme',
#   u'SayNO - UNiTE to End Violence Against Women',
#   u'Food and Agriculture Organization of the United Nations (FAO)',
#   u'United Nations Economic and Social Council',
#   u'Ambassador Samantha Power',
#   u'UNEP',
#   u'Sustainable Development Goals Fund',
#   u'IRD',
#   u'UN Women Asia and the Pacific',
#   u'Institute for Health Metrics and Evaluation (IHME)',
#   u'UN Radio',
#   u'UN Peacekeeping',
#   u'Canada is Dedicated to International Development - DFATD',
#   u'Aeras'],
#  [u'Global Moms Challenge',
#   u'Unite For Sight',
#   u'Better Immunization Data Initiative',
#   u'Mobile Alliance for Maternal Action - MAMA Global',
#   u'Sesame Workshop',
#   u'CDC Global',
#   u'A Mighty Girl',
#   u'BlackGirlsCode',
#   u'Show of Force: Social Good',
#   u'Catapult',
#   u'Family Planning 2020',
#   u'Girl Up',
#   u'Plus Social Good',
#   u'International Trachoma Initiative',
#   u'Global Health Strategies',
#   u'TechSoup',
#   u'CNN International',
#   u'Women in the World',
#   u'International Partnership for Microbicides',
#   u'GivingTuesday',
#   u'Bring Back Our Girls',
#   u"Amy Poehler's Smart Girls",
#   u'Women Deliver',
#   u'V-Day',
#   u'Sevenly',
#   u"Girls' Globe",
#   u'10x10 - Girl Rising',
#   u'Bond_Free',
#   u'Girl Effect',
#   u'The Wellbeing Foundation',
#   u'International Justice Mission',
#   u'Day of the Girl'],
#  [u'Dexter',
#   u'Team Gleason',
#   u'HP',
#   u'Microsoft Imagine',
#   u'Best Buy',
#   u'Internet Explorer',
#   u'Microsoft Lumia',
#   u'Team GB',
#   u'Nokia',
#   u'Dell',
#   u'Coca-Cola',
#   u'The Dow Chemical Company',
#   u'CES',
#   u'Grace Hopper Celebration of Women in Computing',
#   u'Microsoft Excel',
#   u'Microsoft Flight',
#   u'Lenovo',
#   u'Intel',
#   u'P&G',
#   u'Windows',
#   u'Microsoft Tag',
#   u'Bing',
#   u'Xbox',
#   u'Tom Daley',
#   u'Microsoft',
#   u'Emma Watson',
#   u'Microsoft Research',
#   u'Outlook',
#   u'Westfield Century City',
#   u'Microsoft Store',
#   u'Xbox Entertainment',
#   u'GroupMe',
#   u'Surface',
#   u'Burn the Rope',
#   u'The Olympic Games',
#   u'Panasonic UK',
#   u'Skype',
#   u'ASUS',
#   u'Acer',
#   u'Panasonic'],
#  [u'STEMconnector',
#   u'Massachusetts Council for the Social Studies',
#   u'San Joaquin Valley Council for the Social Studies (SJVCSS)',
#   u'California Geographic Alliance',
#   u'Kansas Council for the Social Studies',
#   u'PBL for Teachers',
#   u'Big History Project',
#   u'Kentucky Council for the Social Studies',
#   u'US National Archives',
#   u'Wisconsin Council for the Social Studies (WCSS)',
#   u'Minnesota Council for the Social Studies',
#   u'Georgia Council for the Social Studies (GCSS)',
#   u'Washington State Council for the Social Studies',
#   u'Colonial Williamsburg',
#   u'The Bill of Rights Institute',
#   u'Texas Council for the Social Studies',
#   u'National History Day',
#   u'Virginia Council for the Social Studies',
#   u'HISTORY',
#   u'Bradshaw Foundation',
#   u'Center for Civic Education',
#   u'Facing the Future',
#   u'Education Week',
#   u'The Choices Program',
#   u'Skype in the classroom',
#   u'The Georgia Geographic Alliance',
#   u'High Tech Teachers',
#   u'National History Day California',
#   u'National Council for the Social Studies',
#   u'Colorado Council for the Social Studies',
#   u'California Council for the Social Studies',
#   u'Tennessee Council for the Social Studies',
#   u'Social Studies',
#   u'OCSS - The Oregon Council for the Social Studies',
#   u'National Geographic Learning',
#   u'NASA - National Aeronautics and Space Administration',
#   u'National Geographic Education',
#   u'Reagan Library',
#   u'SJSU Social Science Teacher Preparation',
#   u'The Gilder Lehrman Institute of American History',
#   u'New Jersey Geographic Alliance',
#   u'Teaching Tolerance',
#   u'Oklahoma Council for the Social Studies',
#   u'Constitutional Rights Foundation',
#   u'U.S. Department of Agriculture',
#   u'California Charter Schools Association',
#   u'Colorado Geographic Alliance']]

# %%
test_node = 'Bill Gates'
G_train = subgraph.copy()
edges_to_rem = subgraph.edges(test_node)[:10]
G_train.remove_edges_from(edges_to_rem)
print('original graph has %d nodes and %d edges' % 
      (subgraph.order(), subgraph.number_of_edges()))
print('train graph has %d nodes and %d edges' % 
      (G_train.order(), G_train.number_of_edges()))
# Out:
# original graph has 712 nodes and 1710 edges
# train graph has 712 nodes and 1700 edges

# %%
print('removed the following edges:')
edges_to_rem
# Out:
# removed the following edges:
# [('Bill Gates', u'Khan Academy'),
#  ('Bill Gates', u'Pau Gasol'),
#  ('Bill Gates', u'Big History Project'),
#  ('Bill Gates', u'PATH'),
#  ('Bill Gates', u'Vaccines Today'),
#  ('Bill Gates', u'World Health Organization'),
#  ('Bill Gates', u'TED'),
#  ('Bill Gates', u'Bill & Melinda Gates Foundation'),
#  ('Bill Gates', u'ONE'),
#  ('Bill Gates', u'Sue Desmond-Hellmann')]

# %%
# I've done this one for you.
def evaluate(scores, graph, n=10):
    """ Returns the accuracy of the predicted link scores, filtering
        to the top `n` results.
    Args:
      scores....list of ((n1, n2), score) tuples, representing the 
                score assigned to edge (n1, n2)
      graph.....a networkx graph
      n.........Evaluate the top n values in scores.
    Returns:
      A float indicating the proportion of the top ranked edges
      in scores that are present in the graph.
    """
    predicted_edges = [x[0] for x in sorted(scores, key=lambda x: x[1], reverse=True)[:n]]
    return 1. * len([x for x in predicted_edges if graph.has_edge(*x)]) / len(predicted_edges)

# %%
# I've done this one for you.

def jaccard(graph, node):
    """ Jaccard similarity. Note that we don't
    return scores for edges that already appear in the graph.
    """
    scores = []
    neighborsi = set(graph.neighbors(node))
    for n in graph.nodes():
        if n != node and not graph.has_edge(node, n):
            neighborsj = set(graph.neighbors(n))
            score = 1. * (len(neighborsi & neighborsj)) / (len(neighborsi | neighborsj))
            scores.append(((node, n), score))
    return scores

jaccard_scores = jaccard(G_train, test_node)
print('jaccard accuracy=%.3f' % evaluate(jaccard_scores, subgraph, n=10))
# Out:
# jaccard accuracy=0.200

# %%
print('%d jaccard scores' % len(jaccard_scores))
print('top 5 recommendations:')
[x[0][1] for x in sorted(jaccard_scores, key=lambda x: x[1], reverse=True)[:5]]
# Out:
# 690 jaccard scores
# top 5 recommendations:
# [u'Global Citizen',
#  u'Girl Effect',
#  u'Show of Force: Social Good',
#  u'Sue Desmond-Hellmann',
#  u'Global Poverty Project']

# %%
def jaccard_wt(graph, node):
    """
    The weighted jaccard score, defined above.
    Args:
      graph....a networkx graph
      node.....a node to score potential new edges for.
    Returns:
      A list of ((node, ni), score) tuples, representing the 
                score assigned to edge (node, ni)
                (note the edge order)
    """
    ###TODO
    ###
    scores = []
    sumi = 0
    neighborsi = set(graph.neighbors(node))
    
    for i in neighborsi:
        sumi = sumi + graph.degree(i)
    for n in graph.nodes():
        sumj = 0
        sumz = 0
        if n != node and not graph.has_edge(node, n):
            neighborsj = set(graph.neighbors(n))
            x = (neighborsi & neighborsj)
            for j in neighborsj:
                sumj = sumj + graph.degree(j)
            for z in x:
                sumz = sumz + (1.0/graph.degree(z))
            score = (sumz/(1.0/sumi)+(1.0/sumj))
            scores.append(((node, n), score))
    return scores    
                
jaccard_wt_scores = jaccard_wt(G_train, test_node)
print('jaccard_wt accuracy=%.3f' % evaluate(jaccard_wt_scores, subgraph, n=10))
# Out:
# jaccard_wt accuracy=0.400

# %%
print('%d jaccard_wt_scores' % len(jaccard_wt_scores))
print('top 5 recommendations:')
[x[0][1] for x in sorted(jaccard_wt_scores, key=lambda x: x[1], reverse=True)[:5]]
# Out:
# 690 jaccard_wt_scores
# top 5 recommendations:
# [u'Bill & Melinda Gates Foundation',
#  u'Global Citizen',
#  u'Microsoft Research',
#  u'Chase',
#  u'Sue Desmond-Hellmann']

# %%
# Do not modify this cell.
import json
outf = open('output.txt', 'wt')

exgraph = nx.Graph()
exgraph.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'C'),
                        ('B', 'D'), ('D', 'E'), ('D', 'F'),
                        ('D', 'G'), ('E', 'F'), ('G', 'F')])                                        
[sorted(x) for x in girvan_newman(exgraph.copy(), minsize=1, maxsize=2)]

json.dump({'graph_order': read_graph().order(),
           'graph_edges': len(read_graph().edges()),
           'subgraph_order': get_subgraph(read_graph(), 1).order(),
           'subgraph_edges': len(get_subgraph(read_graph(), 1).edges()),
           'subgraph_order_2': get_subgraph(read_graph(), 2).order(),
           'subgraph_edges_2': len(get_subgraph(read_graph(), 2).edges()),
           'gn_1_2': sorted([sorted(x) for x in girvan_newman(exgraph.copy(), minsize=1, maxsize=2)]),
           'gn_2_3': sorted([sorted(x) for x in girvan_newman(exgraph.copy(), minsize=2, maxsize=3)]),
           'gn_1_4': sorted([sorted(x) for x in girvan_newman(exgraph.copy(), minsize=1, maxsize=4)]),
           'volume1': volume(['A', 'B', 'C', 'D'], exgraph),
           'cut1': cut(['A', 'B', 'C', 'D'], ['E', 'F', 'G'], exgraph),
           'ncv1': norm_cut_v(['A', 'B', 'C', 'D'], ['E', 'F', 'G'], exgraph),
           'score_clusters': score_clusters(result, subgraph),
           'gn_sizes': [len(x) for x in result],
           'jaccard_wt': sorted(jaccard_wt(G_train, test_node),
                                key=lambda x: x[1], reverse=True)[:30]
          }, outf, indent=2, sort_keys=True)
outf.close()
# Out:
# removed 1 edges
# Component sizes = [3, 4]
# removed 1 edges
# Component sizes = [3, 4]
# removed 1 edges
# Component sizes = [3, 4]
# removed 1 edges
# Component sizes = [3, 4]
